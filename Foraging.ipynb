# %%
#!pip install lbforaging

# %%
import lbforaging
from games.foraging import Foraging 
import numpy as np
import time
from agents.random_agent import RandomAgent

# %%
game = Foraging(config=None, seed=1)
# Out:
# c:\Users\Guillermo\miniconda3\envs\pettingzoo_games\Lib\site-packages\gymnasium\spaces\box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
game.reset()
for agent in game.agents:
    print(f"Agent {agent}")
    print(f"Observed state: {game.observe(agent)}")
    print(f"Observed actions: {game.observe_action(agent)}")
# Out:
# Agent agent_0
# Observed state: [6. 2. 2. 4. 6. 2. 0. 1. 2.]
# Observed actions: None
# Agent agent_1
# Observed state: [6. 2. 2. 0. 1. 2. 4. 6. 2.]
# Observed actions: None

# %%
def play_episode(game, agents, verbose=False, render=False):

    # Initialize the game
    game.reset()

    # Print initial observations
    if verbose:
        print(f"Step: {game.env.current_step}")
        for agent in game.agents:
            print(f"Agent {agent}: {game.observe(agent)}")

    # Initialize rewards for each agent
    cum_rewards = dict(map(lambda agent: (agent, 0), game.agents))

    # render the game if required
    if render:
        game.render()
        time.sleep(0.5)

    while not game.done():

        # Get actions from each agent
        actions = dict(map(lambda agent: (agent, agents[agent].action()), game.agents))

        # Perform the actions in the game
        game.step(actions)

        # Update the cum_rewards for each agent
        for agent in game.agents:
            cum_rewards[agent] += game.reward(agent)

        # Print the rewards if verbose is enabled
        if verbose:
            print(f"Step: {game.env.current_step}")
            for agent in game.agents:
                print(f"Agent {agent} action: {actions[agent]} ({game.action_set[actions[agent]]})")
                print(f"Agent {agent} reward: {game.reward(agent)}")
                print(f"Agent {agent} next state: {game.observe(agent)}")
                print(f"Agent {agent} joint action: {game.observe_action(agent)}")
        
        if render:
            game.render()
            time.sleep(0.5)
        
    return cum_rewards

# %%
agent_dict = dict(map(lambda agent: (agent, RandomAgent(game=game, agent=agent)), game.agents))

# %%
def run(game, agent_dict, n_episodes=100, verbose=False, render=False):
    total_rewards = dict(map(lambda agent: (agent, 0), game.agents))
    for episode in range(n_episodes):
        if verbose:
            print(f"-- Episode: {episode}")
        cum_rewards = play_episode(game, agent_dict, verbose=verbose, render=render)
        for agent in game.agents:
            total_rewards[agent] += cum_rewards[agent]
        if verbose:
            for agent in game.agents:
                print(f"Total rewards {agent}: {total_rewards[agent]}")
            print("--")
    return total_rewards

# %%
run(game=game, agent_dict=agent_dict, n_episodes=1, verbose=True, render=True)
# Out:
# -- Episode: 0
# Step: 0
# Agent agent_0: [6. 2. 2. 4. 6. 2. 0. 1. 2.]
# Agent agent_1: [6. 2. 2. 0. 1. 2. 4. 6. 2.]
# Step: 1
# Agent agent_0 action: 4 (EAST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 4. 7. 2. 0. 1. 2.]
# Agent agent_0 joint action: (4, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 4. 7. 2.]
# Agent agent_1 joint action: (4, 1)
# Step: 2
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 4. 7. 2. 0. 1. 2.]
# Agent agent_0 joint action: (5, 0)
# Agent agent_1 action: 0 (NONE)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 4. 7. 2.]
# Agent agent_1 joint action: (5, 0)
# Step: 3
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 7. 2. 0. 0. 2.]
# Agent agent_0 joint action: (1, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 0. 2. 3. 7. 2.]
# Agent agent_1 joint action: (1, 3)
# Step: 4
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 7. 2. 0. 1. 2.]
# Agent agent_0 joint action: (5, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 3. 7. 2.]
# Agent agent_1 joint action: (5, 4)
# Step: 5
# Agent agent_0 action: 0 (NONE)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 7. 2. 1. 1. 2.]
# Agent agent_0 joint action: (0, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 1. 2. 3. 7. 2.]
# Agent agent_1 joint action: (0, 2)
# Step: 6
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 7. 2. 1. 1. 2.]
# Agent agent_0 joint action: (1, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 1. 2. 2. 7. 2.]
# Agent agent_1 joint action: (1, 5)
# Step: 7
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 7. 2. 2. 1. 2.]
# Agent agent_0 joint action: (5, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 1. 2. 2. 7. 2.]
# Agent agent_1 joint action: (5, 2)
# Step: 8
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 6. 2. 2. 1. 2.]
# Agent agent_0 joint action: (3, 0)
# Agent agent_1 action: 0 (NONE)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 1. 2. 2. 6. 2.]
# Agent agent_1 joint action: (3, 0)
# Step: 9
# Agent agent_0 action: 0 (NONE)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 6. 2. 1. 1. 2.]
# Agent agent_0 joint action: (0, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 1. 2. 2. 6. 2.]
# Agent agent_1 joint action: (0, 1)
# Step: 10
# Agent agent_0 action: 4 (EAST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 7. 2. 0. 1. 2.]
# Agent agent_0 joint action: (4, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 2. 7. 2.]
# Agent agent_1 joint action: (4, 1)
# Step: 11
# Agent agent_0 action: 0 (NONE)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 7. 2. 0. 1. 2.]
# Agent agent_0 joint action: (0, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 2. 7. 2.]
# Agent agent_1 joint action: (0, 5)
# Step: 12
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 6. 2. 0. 0. 2.]
# Agent agent_0 joint action: (3, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 0. 2. 2. 6. 2.]
# Agent agent_1 joint action: (3, 3)
# Step: 13
# Agent agent_0 action: 2 (SOUTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 6. 2. 0. 0. 2.]
# Agent agent_0 joint action: (2, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 0. 2. 3. 6. 2.]
# Agent agent_1 joint action: (2, 3)
# Step: 14
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 5. 2. 0. 0. 2.]
# Agent agent_0 joint action: (3, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 0. 2. 3. 5. 2.]
# Agent agent_1 joint action: (3, 5)
# Step: 15
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 4. 2. 0. 0. 2.]
# Agent agent_0 joint action: (3, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 0. 2. 3. 4. 2.]
# Agent agent_1 joint action: (3, 3)
# Step: 16
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 4. 2. 0. 1. 2.]
# Agent agent_0 joint action: (1, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 2. 4. 2.]
# Agent agent_1 joint action: (1, 4)
# Step: 17
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 4. 2. 0. 1. 2.]
# Agent agent_0 joint action: (5, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 2. 4. 2.]
# Agent agent_1 joint action: (5, 5)
# Step: 18
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 3. 2. 0. 2. 2.]
# Agent agent_0 joint action: (3, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 2. 3. 2.]
# Agent agent_1 joint action: (3, 4)
# Step: 19
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 3. 2. 0. 3. 2.]
# Agent agent_0 joint action: (1, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 3. 2. 1. 3. 2.]
# Agent agent_1 joint action: (1, 4)
# Step: 20
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 3. 2. 0. 3. 2.]
# Agent agent_0 joint action: (1, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 3. 2. 1. 3. 2.]
# Agent agent_1 joint action: (1, 5)
# Step: 21
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 3. 2. 0. 3. 2.]
# Agent agent_0 joint action: (5, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 3. 2. 1. 3. 2.]
# Agent agent_1 joint action: (5, 5)
# Step: 22
# Agent agent_0 action: 2 (SOUTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 3. 2. 1. 3. 2.]
# Agent agent_0 joint action: (2, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 3. 2. 2. 3. 2.]
# Agent agent_1 joint action: (2, 2)
# Step: 23
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 3. 2. 0. 3. 2.]
# Agent agent_0 joint action: (5, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 3. 2. 2. 3. 2.]
# Agent agent_1 joint action: (5, 1)
# Step: 24
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 2. 2. 0. 2. 2.]
# Agent agent_0 joint action: (3, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 2. 2. 2.]
# Agent agent_1 joint action: (3, 3)
# Step: 25
# Agent agent_0 action: 4 (EAST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 3. 2. 0. 2. 2.]
# Agent agent_0 joint action: (4, 0)
# Agent agent_1 action: 0 (NONE)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 2. 3. 2.]
# Agent agent_1 joint action: (4, 0)
# Step: 26
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 3. 2. 0. 2. 2.]
# Agent agent_0 joint action: (5, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 2. 3. 2.]
# Agent agent_1 joint action: (5, 5)
# Step: 27
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 2. 2. 0. 1. 2.]
# Agent agent_0 joint action: (3, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 1. 2. 2. 2. 2.]
# Agent agent_1 joint action: (3, 3)
# Step: 28
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 2. 2. 0. 2. 2.]
# Agent agent_0 joint action: (1, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 1. 2. 2.]
# Agent agent_1 joint action: (1, 4)
# Step: 29
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 2. 2. 0. 2. 2.]
# Agent agent_0 joint action: (5, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 1. 2. 2.]
# Agent agent_1 joint action: (5, 1)
# Step: 30
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 1. 2. 0. 2. 2.]
# Agent agent_0 joint action: (3, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 1. 1. 2.]
# Agent agent_1 joint action: (3, 5)
# Step: 31
# Agent agent_0 action: 2 (SOUTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 1. 2. 0. 2. 2.]
# Agent agent_0 joint action: (2, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 2. 2. 2. 1. 2.]
# Agent agent_1 joint action: (2, 5)
# Step: 32
# Agent agent_0 action: 2 (SOUTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 1. 2. 0. 3. 2.]
# Agent agent_0 joint action: (2, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 3. 2. 3. 1. 2.]
# Agent agent_1 joint action: (2, 4)
# Step: 33
# Agent agent_0 action: 4 (EAST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 2. 2. 1. 3. 2.]
# Agent agent_0 joint action: (4, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 3. 2. 3. 2. 2.]
# Agent agent_1 joint action: (4, 2)
# Step: 34
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 2. 2. 2. 3. 2.]
# Agent agent_0 joint action: (5, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 3. 2. 3. 2. 2.]
# Agent agent_1 joint action: (5, 2)
# Step: 35
# Agent agent_0 action: 3 (WEST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 1. 2. 2. 4. 2.]
# Agent agent_0 joint action: (3, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 4. 2. 3. 1. 2.]
# Agent agent_1 joint action: (3, 4)
# Step: 36
# Agent agent_0 action: 0 (NONE)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 1. 2. 1. 4. 2.]
# Agent agent_0 joint action: (0, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 4. 2. 3. 1. 2.]
# Agent agent_1 joint action: (0, 1)
# Step: 37
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 1. 2. 1. 4. 2.]
# Agent agent_0 joint action: (5, 0)
# Agent agent_1 action: 0 (NONE)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 4. 2. 3. 1. 2.]
# Agent agent_1 joint action: (5, 0)
# Step: 38
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 1. 2. 2. 4. 2.]
# Agent agent_0 joint action: (1, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 4. 2. 2. 1. 2.]
# Agent agent_1 joint action: (1, 2)
# Step: 39
# Agent agent_0 action: 0 (NONE)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 1. 2. 1. 4. 2.]
# Agent agent_0 joint action: (0, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 4. 2. 2. 1. 2.]
# Agent agent_1 joint action: (0, 1)
# Step: 40
# Agent agent_0 action: 1 (NORTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 1. 2. 0. 4. 2.]
# Agent agent_0 joint action: (1, 1)
# Agent agent_1 action: 1 (NORTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 4. 2. 1. 1. 2.]
# Agent agent_1 joint action: (1, 1)
# Step: 41
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 1. 1. 2. 0. 5. 2.]
# Agent agent_0 joint action: (5, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 5. 2. 1. 1. 2.]
# Agent agent_1 joint action: (5, 4)
# Step: 42
# Agent agent_0 action: 2 (SOUTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 1. 2. 0. 4. 2.]
# Agent agent_0 joint action: (2, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 0. 4. 2. 2. 1. 2.]
# Agent agent_1 joint action: (2, 3)
# Step: 43
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 1. 2. 1. 4. 2.]
# Agent agent_0 joint action: (5, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 4. 2. 2. 1. 2.]
# Agent agent_1 joint action: (5, 2)
# Step: 44
# Agent agent_0 action: 0 (NONE)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 1. 2. 1. 3. 2.]
# Agent agent_0 joint action: (0, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 1. 3. 2. 2. 1. 2.]
# Agent agent_1 joint action: (0, 3)
# Step: 45
# Agent agent_0 action: 4 (EAST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 2. 2. 2. 2. 3. 2.]
# Agent agent_0 joint action: (4, 2)
# Agent agent_1 action: 2 (SOUTH)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 3. 2. 2. 2. 2.]
# Agent agent_1 joint action: (4, 2)
# Step: 46
# Agent agent_0 action: 2 (SOUTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 3. 2. 2. 2. 3. 2.]
# Agent agent_0 joint action: (2, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 3. 2. 3. 2. 2.]
# Agent agent_1 joint action: (2, 5)
# Step: 47
# Agent agent_0 action: 2 (SOUTH)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 4. 2. 2. 2. 4. 2.]
# Agent agent_0 joint action: (2, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 4. 2. 4. 2. 2.]
# Agent agent_1 joint action: (2, 4)
# Step: 48
# Agent agent_0 action: 4 (EAST)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 4. 3. 2. 2. 5. 2.]
# Agent agent_0 joint action: (4, 4)
# Agent agent_1 action: 4 (EAST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 5. 2. 4. 3. 2.]
# Agent agent_1 joint action: (4, 4)
# Step: 49
# Agent agent_0 action: 5 (LOAD)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 4. 3. 2. 2. 4. 2.]
# Agent agent_0 joint action: (5, 3)
# Agent agent_1 action: 3 (WEST)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 4. 2. 4. 3. 2.]
# Agent agent_1 joint action: (5, 3)
# Step: 50
# Agent agent_0 action: 0 (NONE)
# Agent agent_0 reward: 0
# Agent agent_0 next state: [6. 2. 2. 4. 3. 2. 2. 4. 2.]
# Agent agent_0 joint action: (0, 5)
# Agent agent_1 action: 5 (LOAD)
# Agent agent_1 reward: 0
# Agent agent_1 next state: [6. 2. 2. 2. 4. 2. 4. 3. 2.]
# Agent agent_1 joint action: (0, 5)
# Total rewards agent_0: 0
# Total rewards agent_1: 0
# --
# {'agent_0': 0, 'agent_1': 0}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
